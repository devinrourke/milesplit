# %%
# Make Jupyter wider
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# Out:
# <style>.container { width:90% !important; }</style>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('boys5k.csv')
df.describe()
plt.scatter(df['Year'], df['Time'], s=1, c='k', marker='o')
axes = plt.gca()
axes.set_xlim([1999,2017])
axes.set_ylim([500,3500])
plt.show()

# %%
df.describe().round()
# Out:
#            Rank      Time     Grade      Year
# count  526350.0  526350.0  526350.0  526350.0
# mean      431.0    1114.0    1928.0    2010.0
# std       284.0     129.0     405.0       4.0
# min         1.0     850.0       0.0    2000.0
# 25%       183.0    1032.0    2009.0    2008.0
# 50%       394.0    1081.0    2013.0    2011.0
# 75%       661.0    1161.0    2016.0    2014.0
# max      1000.0    3569.0   12100.0    2016.0

# %%
# Who is the fastest?
df['Time'].idxmin()
df.iloc[228735]
# Out:
# Rank                                                          1
# Time                                                      850.4
# Athlete/School                      Dathan Ritzenhein  Rockford
# Grade                                                      2001
# Meet              MHSAA State Championships LP  1st Nov 4, 2000
# Year                                                       2000
# State                                                        MI
# Gender                                                     Boys
# Name: 228735, dtype: object

# %%
# Who is the fastest, in each State?
df.groupby(['State']).head(n=1)
# Out:
#         Rank    Time                                    Athlete/School  Grade  \
# 0          1   959.9                      Tyler Stanfield  Homewood HS   2002
# 9753       1   936.4                 Trevor Dunbar  Kodiak High School   2009
# 16435      1   922.0       Charles Hampton  Brophy College Preparatory   2004
# 27028      1   966.0             Eric Gross  Mountain Home High School      0
# 39748      1   890.0                     Ryan Hall  Big Bear High (SS)   2001
# 55315      1   953.0  Bret Schoolmeester  Denver Christian High School   2002
# 68183      1   931.0        Brian McGovern  Fairfield Prep High School   2001
# 77952      1   946.0                  Ben Stern  Georgetown Day School   2002
# 81260      1   999.9                 Austin Knight  Newark High School   2002
# 93028      1   930.0                        Mike Swope  Winter Park HS   2001
# 106161     1   917.0                   Joe Thorne  Lakeside HS, DeKalb   2002
# 116233     1   990.0         Jeremy Kamakaala  Kamehameha Schools Oahu   2006
# 119259     1  1001.8          Forest Braden  Bonners Ferry High School   2002
# 130027     1   919.0                  Dan Glaz  A.A. Stagg High School   2001
# 138396     1   912.0        Aaron Fisher  Franklin Central High School   2001
# 148319     1   922.0          Ben Glaser  Dowling Catholic High School   2001
# 160122     1   953.8       Scott Loftin  Blue Valley North High School   2001
# 174122     1   916.0                    Bobby Curtis  St. Xavier (Lou)   2003
# 189537     1  1047.0      Nicholas Cannata  Academy of Sacred Heart GC   2007
# 192790     1   961.2              Steven Dewitt  Ellsworth High School   2002
# 206931     1   976.0     Awit Yohanes  Col. Zadok Magruder High School   2003
# 215521     1   948.4                 Matt Pimentel  Austin Prep School   2001
# 228735     1   850.4                       Dathan Ritzenhein  Rockford   2001
# 244989     1   949.2      Nick Schneider  Benilde-St. Margarets School   2001
# 255798     1   964.4                        Robert Stevenson  Pearl HS   2002
# 268094     1   943.1           Jason Sandfort  West Plains High School   2001
# 279867     1   916.0                Seth Watkins  Flathead High School   2001
# 45326      1  864.0  German Fernandez  Riverbank High School (SJ)   2008
# 22024      1  867.2            Bernie Montoya  Cibola High School   2013
# 481261     1  868.0                       Sean McGorty  Chantilly   2013
# 496496     1  871.7    Tanner Anderson  North Central High School   2015
# 446782     1  872.2          Brodey Hasty  BrentwoodH High School   2018
# 419126     1  872.4          David Principe Jr.  La Salle Academy   2017
#
#                                                      Meet  Year State Gender
# 228735      MHSAA State Championships LP  1st Nov 4, 2000  2000    MI   Boys
# 321789       Essex County Championships  1st Oct 26, 2012  2012    NJ   Boys
# 320789       Essex County Championships  1st Oct 28, 2011  2011    NJ   Boys
# 484278        Third Battle Invitational  1st Oct 17, 2015  2015    VA   Boys
# 45326   CIF State Cross Country Championships  1st Nov...  2007    CA   Boys
# 22024              Division 1 Section 1  1st Oct 26, 2012  2012    AZ   Boys
# 481261       Foot Locker South Regional  1st Nov 24, 2012  2012    VA   Boys
# 496496           WIAA State Championship  1st Nov 8, 2014  2014    WA   Boys
# 446782  Great American Cross Country Festival  1st Sep...  2016    TN   Boys
# 419126  Great American Cross Country Festival  2nd Sep...  2016    RI   Boys

# %%
df.groupby('State').describe().drop('Grade',1).round()
# Out:
#                 Rank     Time     Year
# State
# AK    count   6682.0   6682.0   6682.0
#       mean     407.0   1221.0   2013.0
#       std      266.0    165.0      2.0
#       min        1.0    884.0   2007.0
#       25%      167.0   1107.0   2011.0
#       50%      386.0   1194.0   2013.0
#       75%      625.0   1296.0   2015.0
#       max     1000.0   2510.0   2016.0
# AL    count   9753.0   9753.0   9753.0
#       mean     477.0   1125.0   2012.0
#       std      291.0     75.0      3.0
#       min        1.0    903.0   2001.0
#       25%      220.0   1075.0   2009.0
#       50%      462.0   1128.0   2012.0
#       75%      730.0   1171.0   2014.0
#       max     1000.0   2029.0   2016.0
# AR    count  12720.0  12720.0  12720.0
#       mean     409.0   1226.0   2009.0
#       std      264.0    146.0      5.0
#       min        1.0    903.0   2000.0
#       25%      188.0   1124.0   2006.0
#       50%      376.0   1205.0   2010.0
#       75%      605.0   1301.0   2013.0
#       max     1000.0   2965.0   2016.0
# AZ    count  10593.0  10593.0  10593.0
#       mean     481.0   1097.0   2011.0
#       std      293.0     91.0      3.0
#       min        1.0    867.0   2002.0
#       25%      220.0   1043.0   2009.0
#       50%      471.0   1089.0   2011.0
# ...              ...      ...      ...
# WA    std      270.0     68.0      5.0
#       min        1.0    872.0   2000.0
#       25%      193.0   1008.0   2005.0
#       50%      388.0   1043.0   2010.0
#       75%      605.0   1076.0   2013.0
#       max     1000.0   1922.0   2016.0
# WI    count  12082.0  12082.0  12082.0
#       mean     415.0   1050.0   2010.0
#       std      282.0     60.0      4.0
#       min        1.0    879.0   2000.0
#       25%      178.0   1019.0   2007.0
#       50%      361.0   1048.0   2010.0
#       75%      643.0   1070.0   2013.0
#       max     1000.0   2128.0   2016.0
# WV    count   9061.0   9061.0   9061.0
#       mean     395.0   1243.0   2011.0
#       std      276.0    184.0      4.0
#       min        1.0    898.0   2000.0
#       25%      137.0   1115.0   2009.0
#       50%      368.0   1205.0   2012.0
#       75%      624.0   1328.0   2014.0
#       max     1000.0   2588.0   2016.0
# WY    count   5710.0   5710.0   5710.0
#       mean     226.0   1227.0   2011.0
#       std      161.0    171.0      4.0
#       min        1.0    918.0   2000.0
#       25%       91.0   1110.0   2008.0
#       50%      187.0   1193.0   2012.0
#       75%      350.0   1304.0   2014.0
#       max      626.0   2346.0   2016.0
#
# [408 rows x 3 columns]

# %%
x_total = df.groupby(['Year']).mean()['Time']
print x_total
print type(x_total)
x_total.plot()
plt.axis([1998, 2018, 1050, 1200])
plt.ylabel('seconds')
plt.title('nationwide average 5k time, boys')
plt.show()
# Out:
# Year
# 2000    1107.947202
# 2001    1124.204098
# 2002    1129.015778
# 2003    1131.101956
# 2004    1143.945378
# 2005    1138.017603
# 2006    1143.092192
# 2007    1133.859888
# 2008    1118.603867
# 2009    1119.092364
# 2010    1111.777282
# 2011    1107.832558
# 2012    1105.200577
# 2013    1104.556684
# 2014    1105.123458
# 2015    1101.637753
# 2016    1105.522247
# Name: Time, dtype: float64
# <class 'pandas.core.series.Series'>

# %%
x_state = df.groupby(['State','Year']).mean()['Time']

ind = 0
for key in sorted(df['Time'].groupby([df['State']]).groups.keys()):    
    ind = ind + 1 
    plt.subplot(6, 10, ind)
    plt.xticks([])
    frame1 = plt.gca()
    frame1.axes.get_xaxis().set_visible(False)
    x_state[key].fillna(0).plot.scatter(title = key, figsize = (16, 9),
                                yticks = [900, 1150, 1400], fontsize = 12, sharey = True, sharex = False)
    plt.axis([1998, 2018, 850, 1450])
    plt.tight_layout()
    plt.xlabel('')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-239-2791c8c9696d> in <module>()
#       8     frame1 = plt.gca()
#       9     frame1.axes.get_xaxis().set_visible(False)
# ---> 10     x_state[key].fillna(0).plot.scatter(title = key, figsize = (16, 9),
#      11                                 yticks = [900, 1150, 1400], fontsize = 12, sharey = True, sharex = False)
#      12     plt.axis([1998, 2018, 850, 1450])
#
# AttributeError: 'SeriesPlotMethods' object has no attribute 'scatter'

# %% [markdown]
# # Completeness of the data

# %%
years = ['2000','2001','2002','2003','2004','2005','2006','2007',
         '2008','2009','2010','2011','2012','2013','2014','2015','2016']
years = map(int,years)

ind = 0
for key in sorted(df['Time'].groupby([df['State']]).groups.keys()):    
    ind = ind + 1
    ax = plt.subplot(6, 10, ind)
    plt.axis([2000, 2016, 0, 1000])
    plt.xticks([])
    frame1 = plt.gca()
    frame1.axes.get_xaxis().set_visible(False)
    df['Time'].groupby([df['State'], df['Year']]).count().get(key).reindex(index=years).plot.bar(
        title = key, figsize = (16, 9), fontsize = 12, sharey = True, sharex = False) 
    plt.tight_layout()
    plt.xlabel('')
plt.show()
