# %%
# Make Jupyter wider
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime
# Out:
# <style>.container { width:90% !important; }</style>

# %% [markdown]
# # Read in .csv files

# %%
df = pd.read_csv('5K.csv')
dfb = pd.read_csv('boys5K.csv')
dfg = pd.read_csv('girls5K.csv')

import os
df_size = os.path.getsize('5K.csv')
dfb_size = os.path.getsize('boys5K.csv')
dfg_size = os.path.getsize('girls5K.csv')

print df_size
print dfb_size
print dfg_size
# Out:
# 109792334
# 60695398
# 49097108

# %% [markdown]
# # Learn about the data

# %%
df.head()
# Out:
#    Rank    Time                Athlete/School  Grade  \
# 0     1   959.9  Tyler Stanfield  Homewood HS   2002
# 1     2  1077.4  Scott Fuqua  Oak Mountain HS   2002
# 2     1  1032.3        Robert Bedsole  Hoover   2005
# 3     2  1103.2    Joshua Pawlik  Homewood HS   2005
# 4     3  1109.7       Jeremy Moujoodi  Hoover   2006
#
#                                                 Meet  Year State Gender
# 0       Foot Locker Nationals 2001  26th Dec 8, 2001  2001    AL   Boys
# 1       Foot Locker Nationals 2001  32nd Dec 8, 2001  2001    AL   Boys
# 2  USATF National Junior Olympic XC Championships...  2002    AL   Boys
# 3  USATF National Junior Olympic XC Championships...  2002    AL   Boys
# 4  USATF National Junior Olympic XC Championships...  2002    AL   Boys

# %%
print len(df.index)
# Out:
# 948591

# %%
boys = df.groupby('Gender').get_group('Boys')
girls = df.groupby('Gender').get_group('Girls')
print str(len(boys)) + ' boy records since 2000'
print str(len(girls)) + ' girl records since 2000'
# Out:
# 526350 boy records since 2000
# 422241 girl records since 2000

# %%
print df.dtypes
# Out:
# Rank                int64
# Time              float64
# Athlete/School     object
# Grade               int64
# Meet               object
# Year                int64
# State              object
# Gender             object
# dtype: object

# %%
## Fastest boys times run since 2000
boys.sort_values('Time').head(10)
# Out:
#         Rank   Time                                Athlete/School  Grade  \
# 228735     1  850.4                   Dathan Ritzenhein  Rockford   2001
# 321789     1  858.7          Edward Cheserek  St. Benedict's Prep   2013
# 320789     1  860.0          Edward Cheserek  St. Benedict's Prep   2013
# 484278     1  860.8                 Andrew Hunter  Loudoun Valley   2016
# 45326      1  864.0  German Fernandez  Riverbank High School (SJ)   2008
# 22024      1  867.2            Bernie Montoya  Cibola High School   2013
# 481261     1  868.0                       Sean McGorty  Chantilly   2013
# 496496     1  871.7    Tanner Anderson  North Central High School   2015
# 446782     1  872.2          Brodey Hasty  BrentwoodH High School   2018
# 419126     1  872.4          David Principe Jr.  La Salle Academy   2017
#
#                                                      Meet  Year State Gender
# 228735      MHSAA State Championships LP  1st Nov 4, 2000  2000    MI   Boys
# 321789       Essex County Championships  1st Oct 26, 2012  2012    NJ   Boys
# 320789       Essex County Championships  1st Oct 28, 2011  2011    NJ   Boys
# 484278        Third Battle Invitational  1st Oct 17, 2015  2015    VA   Boys
# 45326   CIF State Cross Country Championships  1st Nov...  2007    CA   Boys
# 22024              Division 1 Section 1  1st Oct 26, 2012  2012    AZ   Boys
# 481261       Foot Locker South Regional  1st Nov 24, 2012  2012    VA   Boys
# 496496           WIAA State Championship  1st Nov 8, 2014  2014    WA   Boys
# 446782  Great American Cross Country Festival  1st Sep...  2016    TN   Boys
# 419126  Great American Cross Country Festival  2nd Sep...  2016    RI   Boys

# %%
## Fastest girls times run since 2000
girls.sort_values('Time').head(10)
# Out:
#         Rank    Time                                 Athlete/School  Grade  \
# 560641     1   984.1          Amber Trotter  Ukiah High School (NC)   2002
# 821727     1   987.0                  Ryen Frazier  Unattached (NC)   2015
# 916838     1   989.0              Weini Kelati  Heritage (Leesburg)   2016
# 926262     1   991.1     Amy-Eloise Neale  Glacier Peak High School   2013
# 567478     1   992.0            Nikki Hiltz  Aptos High School (CC)   2013
# 573491     1   992.1  Fiona O'Keeffe  Davis Senior High School (SJ)   2016
# 927262     1   995.0             Alexa Efraimson  Camas High School   2015
# 822728     1   996.1                  Nevada Mareno  Leesville Road   2017
# 538811     1  1000.0     Allie Ostrander  Kenai Central High School   2015
# 572486     1  1000.0  Fiona O'Keeffe  Davis Senior High School (SJ)   2016
#
#                                                      Meet  Year State Gender
# 560641        Foot Locker Nationals 2001  1st Dec 8, 2001  2001    CA  Girls
# 821727       Foot Locker South Regional  1st Nov 29, 2014  2014    NC  Girls
# 916838        Third Battle Invitational  1st Oct 17, 2015  2015    VA  Girls
# 926262           Sundodger Invitational  1st Sep 15, 2012  2012    WA  Girls
# 567478  CIF California Cross Country State Meet  106th...  2009    CA  Girls
# 573491            Stanford Invitational  1st Sep 26, 2015  2015    CA  Girls
# 927262       Bill Dellinger Invitational  1st Oct 5, 2013  2013    WA  Girls
# 822728    CAP 8 Conference Championship  1st Oct 20, 2015  2015    NC  Girls
# 538811               Palmer Invitational  1st Sep 6, 2014  2014    AK  Girls
# 572486            Stanford Invitational  1st Sep 27, 2014  2014    CA  Girls

# %%
df.iloc[boys.Time.idxmin()]
# Out:
# Rank                                                          1
# Time                                                      850.4
# Athlete/School                      Dathan Ritzenhein  Rockford
# Grade                                                      2001
# Meet              MHSAA State Championships LP  1st Nov 4, 2000
# Year                                                       2000
# State                                                        MI
# Gender                                                     Boys
# Name: 228735, dtype: object

# %%
df.iloc[girls.Time.idxmin()]
# Out:
# Rank                                                        1
# Time                                                    984.1
# Athlete/School          Amber Trotter  Ukiah High School (NC)
# Grade                                                    2002
# Meet              Foot Locker Nationals 2001  1st Dec 8, 2001
# Year                                                     2001
# State                                                      CA
# Gender                                                  Girls
# Name: 560641, dtype: object

# %%
avg_5k = datetime.timedelta(seconds = df.Time.mean())
boys_avg_5k = datetime.timedelta(seconds = boys.Time.mean())
girls_avg_5k = datetime.timedelta(seconds = girls.Time.mean())

print 'Average 5K: ' + str(avg_5k)
print 'Boys Average 5K: ' +  str(boys_avg_5k)
print 'Girls Average 5K: ' + str(girls_avg_5k)
# Out:
# Average 5K: 0:20:18.947700
# Boys Average 5K: 0:18:34.368611
# Girls Average 5K: 0:22:29.312121

# %% [markdown]
# # Let's plot!

# %%
f, (ax1, ax2) = plt.subplots(1, 2, sharey = True)
ax1.scatter(boys.Year, boys.Time, s = 1, marker = ".", color = 'b')
ax1.set_title('Boys')
ax1.set_xlim([1999, 2017])
ax1.set_ylim([700, 4000])
ax2.scatter(girls.Year, girls.Time, s = 1, marker = ".", color = 'm')
ax2.set_title('Girls')
ax2.set_xlim([1999, 2017])

plt.tight_layout()
plt.show()

# %% [markdown]
# # Check completeness of the data

# %%
years = ['2000','2001','2002','2003','2004','2005','2006','2007',
         '2008','2009','2010','2011','2012','2013','2014','2015','2016']
years = map(int, years)

ind = 0
for key in sorted(df.Time.groupby(df.State).groups.keys()):    
    ind = ind + 1
    ax = plt.subplot(6, 10, ind)
    plt.axis([2000, 2016, 0, 1000])
    plt.xticks([])
    frame1 = plt.gca()
    frame1.axes.get_xaxis().set_visible(False)
    df.Time.groupby([df.State, df.Year]).count().get(key).reindex(index=years).plot.bar(
        title = key, figsize = (16, 9), fontsize = 12, sharey = True, sharex = False) 
    plt.tight_layout()
    plt.xlabel('')
plt.show()

# %% [markdown]
# # Other fun stats

# %%
## State Record holding Boys (only online records, only dating back to 2000)
boys.sort_values('Time').groupby('State').head(n=1).sort_index()
# Out:
#         Rank   Time                                     Athlete/School  Grade  \
# 5752       1  903.3                       Mac Macoy  Vestavia Hills HS   2014
# 12742      1  883.9                    Levi Thomet  Kodiak High School   2015
# 22024      1  867.2                 Bernie Montoya  Cibola High School   2013
# 35748      1  903.0            Jacob Shiohira  Bentonville High School   2015
# 45326      1  864.0       German Fernandez  Riverbank High School (SJ)   2008
# 64183      1  886.5        Cerake Geberkidane  Denver East High School   2014
# 74935      1  887.0                   Alex Ostberg  Darien High School   2015
# 78661      1  916.5          Mike Crozier  Gonzaga College High School   2012
# 91211      1  906.8         Kevin Murray  Charter School of Wilmington   2016
# 98158      1  891.0                             Matt Mizereck  Leon HS   2010
# 110230     1  881.0         Josh Brickell  Peachtree Ridge High School   2013
# 117748     1  922.2                Kaeo Kruse  Kamehameha Schools Oahu   2016
# 127027     1  901.0            Elijah Armstrong  Pocatello High School   2015
# 131385     1  884.2              Lukas Verzbicas  Sandburg High School   2011
# 147317     1  875.0                 Curtis Eckstein  Oldenburg Academy   2017
# 149129     1  884.0                 Ellen Ries  North-Linn High School   2005
# 170119     1  898.3        Stuart Mcnutt  Blue Valley West High School   2015
# 184534     1  883.9             Jacob Thomson  Holy Cross (Louisville)   2013
# 192187     1  903.8                     Eric Coston  St. Paul's School   2017
# 193921     1  902.0                       Ben True  Greely High School   2004
# 211518     1  907.9                     Tyler Spear  Loyola-Blakefield   2014
# 221729     1  905.2         John Murray  Shrewsbury Senior High School   2011
# 228735     1  850.4                        Dathan Ritzenhein  Rockford   2001
# 254798     1  894.1                  Seth Eliason  Hopkins High School   2017
# 260094     1  919.2                     Max Holman  Tupelo High School   2010
# 272858     1  900.6            Caleb Hoover  College Heights Christian   2011
# 281620     1  904.4              Marshall Beatty  Sentinel High School   2017
# 291693     1  879.5              Seth Hirsch  Millard West High School   2017
# 299459     1  899.7                Henry Weisberg  McQueen High School   2017
# 309340     1  903.4          Patrick O'brien  Oyster River High School   2017
# 321789     1  858.7               Edward Cheserek  St. Benedict's Prep   2013
# 330528     1  894.4           Luis Martinez  Sue Cleveland High School   2013
# 345062     1  887.0                     Jeriqho Gadway  Plattsburgh HS   2015
# 357289     1  884.0                 Ben Huffman  Providence Day School   2014
# 364940     1  896.0                Jake Leingang  Bismarck High School   2013
# 378939     1  884.7                    Andrew Jordan  Watkins Memorial   2016
# 797120  Girls
# 804596  Girls
# 821727  Girls
# 825212  Girls
# 837503  Girls
# 838778  Girls
# 851753  Girls
# 861891  Girls
# 866418  Girls
# 873588  Girls
# 876590  Girls
# 885885  Girls
# 892879  Girls
# 899443  Girls
# 907453  Girls
# 916838  Girls
# 926262  Girls
# 935469  Girls
# 939129  Girls
# 948147  Girls

# %%
## quick glance at any given state
boys.groupby('State').get_group('CO').describe().drop('Grade', 1).round()
# girls.groupby('State').get_group('CO').describe().drop('Grade', 1).round()
# Out:
#           Rank     Time     Year
# count  12868.0  12868.0  12868.0
# mean     438.0   1079.0   2010.0
# std      280.0     74.0      4.0
# min        1.0    886.0   2000.0
# 25%      201.0   1036.0   2007.0
# 50%      401.0   1074.0   2010.0
# 75%      667.0   1107.0   2013.0
# max     1000.0   1957.0   2016.0

# %%
boys.Time.groupby(df.Year).mean().plot(color = 'b')
plt.axis([1998, 2018, 1050, 1450])
plt.ylabel('seconds')
plt.title('nationwide average 5k time, boys')
plt.show()

# %%
girls.Time.groupby(df.Year).mean().plot(color = 'm')
plt.axis([1998, 2018, 1050, 1450])
plt.ylabel('seconds')
plt.title('nationwide average 5k time, girls')
plt.show()

# %%
boys.Time.groupby(df.Year).mean().plot(color = 'b')
girls.Time.groupby(df.Year).mean().plot(color = 'm')
plt.axis([1998, 2018, 1050, 1450])
plt.ylabel('seconds')
plt.title('nationwide average 5k time')
plt.show()

# %%
df2 = boys.Time.groupby([df.State, df.Year]).mean()

ind = 0
for key in sorted(df.Time.groupby(df.State).groups.keys()):    
    ind = ind + 1 
    plt.subplot(6, 10, ind)
    plt.xticks([])
    frame1 = plt.gca()
    frame1.axes.get_xaxis().set_visible(False)
    df2[key].fillna(0).plot(title = key, figsize = (16, 9), yticks = [900, 1150, 1400],
                            color = 'b', fontsize = 12, sharey = True, sharex = False)
    plt.axis([1999, 2017, 850, 1450])
    plt.tight_layout()
    plt.xlabel('')
plt.show()

# %%
df3 = girls.Time.groupby([df.State, df.Year]).mean()

ind = 0
for key in sorted(df.Time.groupby(df.State).groups.keys()):    
    ind = ind + 1 
    plt.subplot(6, 10, ind)
    plt.xticks([])
    frame1 = plt.gca()
    frame1.axes.get_xaxis().set_visible(False)
    df3[key].fillna(0).plot(title = key, figsize = (16, 9), yticks = [900, 1150, 1400],
                            color = 'm', fontsize = 12, sharey = True, sharex = False)
    plt.axis([1999, 2017, 1000, 1700])
    plt.tight_layout()
    plt.xlabel('')
plt.show()

# %%
ind = 0
for key in sorted(df.Time.groupby(df.State).groups.keys()):    
    ind = ind + 1 
    plt.subplot(6, 10, ind)
    plt.xticks([])
    frame1 = plt.gca()
    frame1.axes.get_xaxis().set_visible(False)
    df2[key].fillna(0).plot(title = key, figsize = (16, 9), yticks = [900, 1150, 1400],
                            color = 'b', fontsize = 12, sharey = True, sharex = False)
    df3[key].fillna(0).plot(title = key, figsize = (16, 9), yticks = [900, 1150, 1400],
                            color = 'm', fontsize = 12, sharey = True, sharex = False)
    plt.axis([1998, 2018, 850, 1700])
    plt.tight_layout()
    plt.xlabel('')
plt.show()
